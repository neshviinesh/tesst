# %%
# !pip install kafka-python psycopg2
# Out:
# Requirement already satisfied: kafka-python in c:\users\user\anaconda3\envs\proximity_backend\lib\site-packages (2.2.11)
# Requirement already satisfied: psycopg2 in c:\users\user\anaconda3\envs\proximity_backend\lib\site-packages (2.9.10)

# %%
from uuid import uuid4

for _ in range(5):
    uid = str(uuid4())
    cur.execute("""
        INSERT INTO app_user (user_id, face_embedding, push_token, phone_number, consent_version)
        VALUES (%s, %s, %s, %s, %s)
    """, (uid, b'\x00'*512, None, 'hashed', 'v1'))

conn.commit()
print("✅ Inserted 5 fake users.")
# Out:
# ✅ Inserted 5 fake users.

# %%
from kafka import KafkaConsumer
import psycopg2
import json
from datetime import datetime
from math import radians, sin, cos, sqrt, atan2

# %%
def haversine(lat1, lon1, lat2, lon2):
    R = 6371000  # Earth radius in meters
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    a = sin(dlat/2)**2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    return R * c

# %%
conn = psycopg2.connect(
    host="localhost",
    database="campus_surveillance",
    user="postgres",
    password="123456789"
)
cur = conn.cursor()

print("✅ Connected to PostgreSQL.")
# Out:
# ✅ Connected to PostgreSQL.

# %%
cur.execute("SELECT user_id FROM app_user")
valid_users = [row[0] for row in cur.fetchall()]
print(f"✅ Found {len(valid_users)} users.")
# Out:
# ✅ Found 5 users.

# %%
consumer = KafkaConsumer(
    "detections",
    bootstrap_servers='localhost:9092',
    value_deserializer=lambda m: json.loads(m.decode('utf-8')),
    auto_offset_reset='earliest',
    enable_auto_commit=True
)

print("📡 Listening for events...")

for msg in consumer:
    data = msg.value
    user_id = data["user_id"]
    cam_id = data["cam_id"]
    user_lat = data["user_lat"]
    user_lon = data["user_lon"]
    confidence = data["confidence"]

    # Only accept if user_id exists
    if user_id not in valid_users:
        print(f"❌ Skipping unknown user_id: {user_id}")
        continue

    # Get camera location
    cur.execute("SELECT lat, lon FROM camera WHERE cam_id = %s", (cam_id,))
    cam = cur.fetchone()
    if not cam:
        print(f"❌ Camera ID {cam_id} not found.")
        continue

    cam_lat, cam_lon = float(cam[0]), float(cam[1])
    distance = haversine(user_lat, user_lon, cam_lat, cam_lon)
    is_nearby = distance < 500

    # Insert detection event
    cur.execute("""
        INSERT INTO detection_event (user_id, cam_id, timestamp_utc, confidence, distance_m, delivered)
        VALUES (%s, %s, %s, %s, %s, %s)
    """, (user_id, cam_id, datetime.utcnow(), confidence, distance, is_nearby))
    conn.commit()

    print(f"✅ Event saved | Cam: {cam_id} | Distance: {round(distance)}m | Alert: {is_nearby}")

# %%
msg_count = 0
max_msgs = 500  # Adjust as needed

for msg in consumer:
    data = msg.value
    user_id = data["user_id"]
    cam_id = data["cam_id"]
    user_lat = data["user_lat"]
    user_lon = data["user_lon"]
    confidence = data["confidence"]

    # Get camera location
    cur.execute("SELECT lat, lon FROM camera WHERE cam_id = %s", (cam_id,))
    cam = cur.fetchone()
    if not cam:
        print(f"❌ Camera ID {cam_id} not found.")
        continue

    cam_lat, cam_lon = float(cam[0]), float(cam[1])
    distance = haversine(user_lat, user_lon, cam_lat, cam_lon)
    is_nearby = distance < 500

    cur.execute("""
        INSERT INTO detection_event (user_id, cam_id, timestamp_utc, confidence, distance_m, delivered)
        VALUES (%s, %s, %s, %s, %s, %s)
    """, (user_id, cam_id, datetime.utcnow(), confidence, distance, is_nearby))
    conn.commit()

    print(f"✅ Saved: Cam {cam_id}, Dist: {round(distance)}m | Alert: {is_nearby}")

    msg_count += 1
    if msg_count >= max_msgs:
        print(f"🔁 Processed {msg_count} messages, exiting.")
        break
# Out:
# ✅ Saved: Cam 10, Dist: 207m | Alert: True
# ✅ Saved: Cam 7, Dist: 334m | Alert: True
# ✅ Saved: Cam 4, Dist: 260m | Alert: True
# ✅ Saved: Cam 4, Dist: 214m | Alert: True
# ✅ Saved: Cam 6, Dist: 242m | Alert: True
# ✅ Saved: Cam 10, Dist: 152m | Alert: True
# ✅ Saved: Cam 4, Dist: 375m | Alert: True
# ✅ Saved: Cam 2, Dist: 138m | Alert: True
# ✅ Saved: Cam 1, Dist: 391m | Alert: True
# ✅ Saved: Cam 3, Dist: 111m | Alert: True
# ✅ Saved: Cam 7, Dist: 307m | Alert: True
# ✅ Saved: Cam 2, Dist: 226m | Alert: True
# ✅ Saved: Cam 9, Dist: 150m | Alert: True
# ✅ Saved: Cam 3, Dist: 272m | Alert: True
# ✅ Saved: Cam 9, Dist: 92m | Alert: True
# ✅ Saved: Cam 2, Dist: 150m | Alert: True
# ✅ Saved: Cam 9, Dist: 155m | Alert: True
# ✅ Saved: Cam 4, Dist: 394m | Alert: True
# ✅ Saved: Cam 8, Dist: 245m | Alert: True
# ✅ Saved: Cam 8, Dist: 135m | Alert: True
# ✅ Saved: Cam 10, Dist: 104m | Alert: True
# ✅ Saved: Cam 1, Dist: 379m | Alert: True
# ✅ Saved: Cam 10, Dist: 176m | Alert: True
# ✅ Saved: Cam 6, Dist: 90m | Alert: True
# ✅ Saved: Cam 10, Dist: 204m | Alert: True
# ✅ Saved: Cam 3, Dist: 214m | Alert: True
# ✅ Saved: Cam 4, Dist: 360m | Alert: True
# ✅ Saved: Cam 9, Dist: 111m | Alert: True
# ✅ Saved: Cam 8, Dist: 235m | Alert: True
# ✅ Saved: Cam 6, Dist: 111m | Alert: True
# ✅ Saved: Cam 2, Dist: 227m | Alert: True
# ✅ Saved: Cam 5, Dist: 42m | Alert: True
# ✅ Saved: Cam 1, Dist: 365m | Alert: True
# ✅ Saved: Cam 1, Dist: 278m | Alert: True
# ✅ Saved: Cam 9, Dist: 138m | Alert: True
# ✅ Saved: Cam 8, Dist: 183m | Alert: True
# ✅ Saved: Cam 10, Dist: 119m | Alert: True
# ✅ Saved: Cam 6, Dist: 142m | Alert: True
# ✅ Saved: Cam 5, Dist: 161m | Alert: True
# ✅ Saved: Cam 7, Dist: 197m | Alert: True
# ✅ Saved: Cam 5, Dist: 89m | Alert: True
# ✅ Saved: Cam 8, Dist: 159m | Alert: True
# ✅ Saved: Cam 1, Dist: 413m | Alert: True
# ✅ Saved: Cam 1, Dist: 390m | Alert: True
# ✅ Saved: Cam 9, Dist: 137m | Alert: True
# ✅ Saved: Cam 10, Dist: 213m | Alert: True
# ✅ Saved: Cam 7, Dist: 250m | Alert: True
# ✅ Saved: Cam 8, Dist: 272m | Alert: True
# ✅ Saved: Cam 6, Dist: 137m | Alert: True
# ✅ Saved: Cam 1, Dist: 275m | Alert: True
# ✅ Saved: Cam 8, Dist: 120m | Alert: True
# ✅ Saved: Cam 6, Dist: 106m | Alert: True
# ✅ Saved: Cam 6, Dist: 238m | Alert: True
# ✅ Saved: Cam 5, Dist: 112m | Alert: True
# ✅ Saved: Cam 5, Dist: 38m | Alert: True
# ✅ Saved: Cam 8, Dist: 251m | Alert: True
# ✅ Saved: Cam 10, Dist: 115m | Alert: True
# ✅ Saved: Cam 2, Dist: 158m | Alert: True
# ✅ Saved: Cam 10, Dist: 114m | Alert: True
# ✅ Saved: Cam 7, Dist: 270m | Alert: True
# ✅ Saved: Cam 7, Dist: 302m | Alert: True
# ✅ Saved: Cam 2, Dist: 160m | Alert: True
# ✅ Saved: Cam 6, Dist: 288m | Alert: True
# ✅ Saved: Cam 8, Dist: 245m | Alert: True
# ✅ Saved: Cam 8, Dist: 180m | Alert: True
# ✅ Saved: Cam 3, Dist: 246m | Alert: True
# ✅ Saved: Cam 10, Dist: 90m | Alert: True
# ✅ Saved: Cam 1, Dist: 420m | Alert: True
# ✅ Saved: Cam 10, Dist: 98m | Alert: True
# ✅ Saved: Cam 9, Dist: 144m | Alert: True
# ✅ Saved: Cam 5, Dist: 122m | Alert: True
# ✅ Saved: Cam 3, Dist: 248m | Alert: True
# ✅ Saved: Cam 9, Dist: 141m | Alert: True
# ✅ Saved: Cam 2, Dist: 110m | Alert: True
# ✅ Saved: Cam 5, Dist: 221m | Alert: True
# ✅ Saved: Cam 10, Dist: 88m | Alert: True
# ✅ Saved: Cam 5, Dist: 70m | Alert: True
# ✅ Saved: Cam 9, Dist: 59m | Alert: True
# ✅ Saved: Cam 10, Dist: 155m | Alert: True
# ✅ Saved: Cam 9, Dist: 176m | Alert: True
# ✅ Saved: Cam 4, Dist: 335m | Alert: True
# ✅ Saved: Cam 10, Dist: 104m | Alert: True
# ✅ Saved: Cam 4, Dist: 388m | Alert: True
# ✅ Saved: Cam 9, Dist: 212m | Alert: True
# ✅ Saved: Cam 10, Dist: 92m | Alert: True
# ✅ Saved: Cam 4, Dist: 350m | Alert: True
# ✅ Saved: Cam 10, Dist: 57m | Alert: True
# ✅ Saved: Cam 9, Dist: 216m | Alert: True
# ✅ Saved: Cam 9, Dist: 200m | Alert: True
# ✅ Saved: Cam 7, Dist: 232m | Alert: True
# ✅ Saved: Cam 9, Dist: 120m | Alert: True
# ✅ Saved: Cam 4, Dist: 273m | Alert: True
# ✅ Saved: Cam 6, Dist: 119m | Alert: True
# ✅ Saved: Cam 2, Dist: 112m | Alert: True
# ✅ Saved: Cam 6, Dist: 83m | Alert: True
# ✅ Saved: Cam 7, Dist: 153m | Alert: True
# ✅ Saved: Cam 10, Dist: 53m | Alert: True
# ✅ Saved: Cam 5, Dist: 162m | Alert: True
# ✅ Saved: Cam 3, Dist: 288m | Alert: True
# ✅ Saved: Cam 2, Dist: 277m | Alert: True
# ✅ Saved: Cam 8, Dist: 242m | Alert: True
# ✅ Saved: Cam 6, Dist: 166m | Alert: True
# ✅ Saved: Cam 10, Dist: 83m | Alert: True
# ✅ Saved: Cam 2, Dist: 198m | Alert: True
# ✅ Saved: Cam 7, Dist: 309m | Alert: True
# ✅ Saved: Cam 10, Dist: 194m | Alert: True
# ✅ Saved: Cam 7, Dist: 219m | Alert: True
# ✅ Saved: Cam 3, Dist: 207m | Alert: True
# ✅ Saved: Cam 4, Dist: 206m | Alert: True
# ✅ Saved: Cam 1, Dist: 276m | Alert: True
# ✅ Saved: Cam 10, Dist: 256m | Alert: True
# ✅ Saved: Cam 10, Dist: 187m | Alert: True
# ✅ Saved: Cam 1, Dist: 304m | Alert: True
# ✅ Saved: Cam 1, Dist: 381m | Alert: True
# ✅ Saved: Cam 5, Dist: 130m | Alert: True
# ✅ Saved: Cam 5, Dist: 114m | Alert: True
# ✅ Saved: Cam 10, Dist: 185m | Alert: True
# ✅ Saved: Cam 3, Dist: 289m | Alert: True
# ✅ Saved: Cam 1, Dist: 331m | Alert: True
# ✅ Saved: Cam 1, Dist: 258m | Alert: True
# ✅ Saved: Cam 4, Dist: 232m | Alert: True
# ✅ Saved: Cam 1, Dist: 283m | Alert: True
# ✅ Saved: Cam 6, Dist: 243m | Alert: True
# ✅ Saved: Cam 9, Dist: 176m | Alert: True
# ✅ Saved: Cam 3, Dist: 214m | Alert: True
# ✅ Saved: Cam 7, Dist: 261m | Alert: True
# ✅ Saved: Cam 6, Dist: 274m | Alert: True
# ✅ Saved: Cam 8, Dist: 231m | Alert: True
# ✅ Saved: Cam 5, Dist: 99m | Alert: True
# ✅ Saved: Cam 1, Dist: 315m | Alert: True
# ✅ Saved: Cam 4, Dist: 237m | Alert: True
# ✅ Saved: Cam 7, Dist: 334m | Alert: True
# ✅ Saved: Cam 8, Dist: 283m | Alert: True
# ✅ Saved: Cam 10, Dist: 125m | Alert: True
# ✅ Saved: Cam 4, Dist: 295m | Alert: True
# ✅ Saved: Cam 10, Dist: 18m | Alert: True
# ✅ Saved: Cam 5, Dist: 100m | Alert: True
# ✅ Saved: Cam 2, Dist: 223m | Alert: True
# ✅ Saved: Cam 7, Dist: 238m | Alert: True
# ✅ Saved: Cam 8, Dist: 183m | Alert: True
# ✅ Saved: Cam 5, Dist: 229m | Alert: True
# ✅ Saved: Cam 3, Dist: 90m | Alert: True
# ✅ Saved: Cam 6, Dist: 82m | Alert: True
# ✅ Saved: Cam 5, Dist: 89m | Alert: True
# ✅ Saved: Cam 6, Dist: 173m | Alert: True
# ✅ Saved: Cam 10, Dist: 213m | Alert: True
# ✅ Saved: Cam 9, Dist: 50m | Alert: True
# ✅ Saved: Cam 8, Dist: 301m | Alert: True
# ✅ Saved: Cam 8, Dist: 294m | Alert: True
# ✅ Saved: Cam 4, Dist: 225m | Alert: True
# ✅ Saved: Cam 10, Dist: 79m | Alert: True
# ✅ Saved: Cam 7, Dist: 276m | Alert: True
# ✅ Saved: Cam 7, Dist: 239m | Alert: True
# ✅ Saved: Cam 7, Dist: 262m | Alert: True
# ✅ Saved: Cam 8, Dist: 251m | Alert: True
# ✅ Saved: Cam 7, Dist: 173m | Alert: True
# ✅ Saved: Cam 6, Dist: 112m | Alert: True
# ✅ Saved: Cam 7, Dist: 280m | Alert: True
# ✅ Saved: Cam 3, Dist: 260m | Alert: True
# ✅ Saved: Cam 5, Dist: 211m | Alert: True
# ✅ Saved: Cam 1, Dist: 288m | Alert: True
# ✅ Saved: Cam 2, Dist: 268m | Alert: True
# ✅ Saved: Cam 5, Dist: 205m | Alert: True
# ✅ Saved: Cam 4, Dist: 255m | Alert: True
# ✅ Saved: Cam 8, Dist: 129m | Alert: True
# ✅ Saved: Cam 3, Dist: 123m | Alert: True
# ✅ Saved: Cam 5, Dist: 38m | Alert: True
# ✅ Saved: Cam 7, Dist: 234m | Alert: True
# ✅ Saved: Cam 5, Dist: 148m | Alert: True
# ✅ Saved: Cam 8, Dist: 162m | Alert: True
# ✅ Saved: Cam 9, Dist: 166m | Alert: True
# ✅ Saved: Cam 4, Dist: 223m | Alert: True
# ✅ Saved: Cam 10, Dist: 206m | Alert: True
# ✅ Saved: Cam 6, Dist: 264m | Alert: True
# ✅ Saved: Cam 8, Dist: 221m | Alert: True
# ✅ Saved: Cam 10, Dist: 181m | Alert: True
# ✅ Saved: Cam 9, Dist: 188m | Alert: True
# ✅ Saved: Cam 2, Dist: 138m | Alert: True
# ✅ Saved: Cam 3, Dist: 364m | Alert: True
# ✅ Saved: Cam 4, Dist: 306m | Alert: True
# ✅ Saved: Cam 8, Dist: 168m | Alert: True
# ✅ Saved: Cam 7, Dist: 412m | Alert: True
# ✅ Saved: Cam 4, Dist: 224m | Alert: True
# ✅ Saved: Cam 10, Dist: 156m | Alert: True
# ✅ Saved: Cam 2, Dist: 112m | Alert: True
# ✅ Saved: Cam 1, Dist: 217m | Alert: True
# ✅ Saved: Cam 3, Dist: 314m | Alert: True
# ✅ Saved: Cam 4, Dist: 374m | Alert: True
# ✅ Saved: Cam 2, Dist: 249m | Alert: True
# ✅ Saved: Cam 9, Dist: 111m | Alert: True
# ✅ Saved: Cam 1, Dist: 261m | Alert: True
# ✅ Saved: Cam 8, Dist: 208m | Alert: True
# ✅ Saved: Cam 1, Dist: 326m | Alert: True
# ✅ Saved: Cam 5, Dist: 50m | Alert: True
# ✅ Saved: Cam 2, Dist: 192m | Alert: True
# ✅ Saved: Cam 8, Dist: 228m | Alert: True
# ✅ Saved: Cam 7, Dist: 302m | Alert: True
# ✅ Saved: Cam 10, Dist: 114m | Alert: True
# ✅ Saved: Cam 9, Dist: 187m | Alert: True
# ✅ Saved: Cam 5, Dist: 64m | Alert: True
# ✅ Saved: Cam 10, Dist: 140m | Alert: True
# ✅ Saved: Cam 6, Dist: 158m | Alert: True
# ✅ Saved: Cam 5, Dist: 6m | Alert: True
# ✅ Saved: Cam 5, Dist: 57m | Alert: True
# ✅ Saved: Cam 8, Dist: 125m | Alert: True
# ✅ Saved: Cam 4, Dist: 256m | Alert: True
# ✅ Saved: Cam 2, Dist: 260m | Alert: True
# ✅ Saved: Cam 1, Dist: 249m | Alert: True
# ✅ Saved: Cam 8, Dist: 281m | Alert: True
# ✅ Saved: Cam 5, Dist: 141m | Alert: True
# ✅ Saved: Cam 3, Dist: 288m | Alert: True
# ✅ Saved: Cam 1, Dist: 275m | Alert: True
# ✅ Saved: Cam 5, Dist: 119m | Alert: True
# ✅ Saved: Cam 2, Dist: 245m | Alert: True
# ✅ Saved: Cam 1, Dist: 300m | Alert: True
# ✅ Saved: Cam 3, Dist: 175m | Alert: True
# ✅ Saved: Cam 9, Dist: 221m | Alert: True
# ✅ Saved: Cam 10, Dist: 134m | Alert: True
# ✅ Saved: Cam 7, Dist: 194m | Alert: True
# ✅ Saved: Cam 8, Dist: 170m | Alert: True
# ✅ Saved: Cam 7, Dist: 385m | Alert: True
# ✅ Saved: Cam 10, Dist: 116m | Alert: True
# ✅ Saved: Cam 5, Dist: 110m | Alert: True
# ✅ Saved: Cam 5, Dist: 178m | Alert: True
# ✅ Saved: Cam 8, Dist: 124m | Alert: True
# ✅ Saved: Cam 9, Dist: 130m | Alert: True
# ✅ Saved: Cam 1, Dist: 364m | Alert: True
# ✅ Saved: Cam 4, Dist: 277m | Alert: True
# ✅ Saved: Cam 6, Dist: 287m | Alert: True
# ✅ Saved: Cam 7, Dist: 276m | Alert: True
# ✅ Saved: Cam 2, Dist: 142m | Alert: True
# ✅ Saved: Cam 6, Dist: 299m | Alert: True
# ✅ Saved: Cam 5, Dist: 161m | Alert: True
# ✅ Saved: Cam 1, Dist: 334m | Alert: True
# ✅ Saved: Cam 5, Dist: 172m | Alert: True
# ✅ Saved: Cam 9, Dist: 182m | Alert: True
# ✅ Saved: Cam 5, Dist: 130m | Alert: True
# ✅ Saved: Cam 1, Dist: 335m | Alert: True
# ✅ Saved: Cam 6, Dist: 243m | Alert: True
# ✅ Saved: Cam 5, Dist: 204m | Alert: True
# ✅ Saved: Cam 5, Dist: 94m | Alert: True
# ✅ Saved: Cam 7, Dist: 180m | Alert: True
# ✅ Saved: Cam 8, Dist: 133m | Alert: True
# ✅ Saved: Cam 10, Dist: 105m | Alert: True
# ✅ Saved: Cam 6, Dist: 96m | Alert: True
# ✅ Saved: Cam 9, Dist: 153m | Alert: True
# ✅ Saved: Cam 3, Dist: 117m | Alert: True
# ✅ Saved: Cam 5, Dist: 81m | Alert: True
# ✅ Saved: Cam 5, Dist: 186m | Alert: True
# ✅ Saved: Cam 7, Dist: 202m | Alert: True
# ✅ Saved: Cam 4, Dist: 304m | Alert: True
# ✅ Saved: Cam 8, Dist: 116m | Alert: True
# ✅ Saved: Cam 4, Dist: 384m | Alert: True
# ✅ Saved: Cam 1, Dist: 333m | Alert: True
# ✅ Saved: Cam 4, Dist: 246m | Alert: True
# ✅ Saved: Cam 1, Dist: 424m | Alert: True
# ✅ Saved: Cam 3, Dist: 249m | Alert: True
# ✅ Saved: Cam 5, Dist: 125m | Alert: True
# ✅ Saved: Cam 2, Dist: 165m | Alert: True
# ✅ Saved: Cam 4, Dist: 432m | Alert: True
# ✅ Saved: Cam 9, Dist: 41m | Alert: True
# ✅ Saved: Cam 4, Dist: 370m | Alert: True
# ✅ Saved: Cam 6, Dist: 263m | Alert: True
# ✅ Saved: Cam 1, Dist: 350m | Alert: True
# ✅ Saved: Cam 7, Dist: 263m | Alert: True
# ✅ Saved: Cam 3, Dist: 267m | Alert: True
# ✅ Saved: Cam 5, Dist: 113m | Alert: True
# ✅ Saved: Cam 2, Dist: 73m | Alert: True
# ✅ Saved: Cam 4, Dist: 279m | Alert: True
# ✅ Saved: Cam 8, Dist: 137m | Alert: True
# ✅ Saved: Cam 9, Dist: 146m | Alert: True
# ✅ Saved: Cam 10, Dist: 143m | Alert: True
# ✅ Saved: Cam 1, Dist: 376m | Alert: True
# ✅ Saved: Cam 3, Dist: 258m | Alert: True
# ✅ Saved: Cam 7, Dist: 225m | Alert: True
# ✅ Saved: Cam 10, Dist: 70m | Alert: True
# ✅ Saved: Cam 2, Dist: 195m | Alert: True
# ✅ Saved: Cam 9, Dist: 69m | Alert: True
# ✅ Saved: Cam 5, Dist: 94m | Alert: True
# ✅ Saved: Cam 8, Dist: 291m | Alert: True
# ✅ Saved: Cam 3, Dist: 299m | Alert: True
# ✅ Saved: Cam 6, Dist: 177m | Alert: True
# ✅ Saved: Cam 4, Dist: 247m | Alert: True
# ✅ Saved: Cam 1, Dist: 234m | Alert: True
# ✅ Saved: Cam 2, Dist: 149m | Alert: True
# ✅ Saved: Cam 8, Dist: 185m | Alert: True
# ✅ Saved: Cam 6, Dist: 172m | Alert: True
# ✅ Saved: Cam 5, Dist: 37m | Alert: True
# ✅ Saved: Cam 4, Dist: 427m | Alert: True
# ✅ Saved: Cam 1, Dist: 336m | Alert: True
# ✅ Saved: Cam 3, Dist: 158m | Alert: True
# ✅ Saved: Cam 4, Dist: 385m | Alert: True
# ✅ Saved: Cam 4, Dist: 307m | Alert: True
# ✅ Saved: Cam 10, Dist: 213m | Alert: True
# ✅ Saved: Cam 6, Dist: 109m | Alert: True
# ✅ Saved: Cam 7, Dist: 362m | Alert: True
# ✅ Saved: Cam 5, Dist: 129m | Alert: True
# ✅ Saved: Cam 8, Dist: 280m | Alert: True
# ✅ Saved: Cam 7, Dist: 301m | Alert: True
# ✅ Saved: Cam 7, Dist: 396m | Alert: True
# ✅ Saved: Cam 4, Dist: 374m | Alert: True
# ✅ Saved: Cam 9, Dist: 67m | Alert: True
# ✅ Saved: Cam 10, Dist: 94m | Alert: True
# ✅ Saved: Cam 7, Dist: 365m | Alert: True
# ✅ Saved: Cam 3, Dist: 164m | Alert: True
# ✅ Saved: Cam 8, Dist: 155m | Alert: True
# ✅ Saved: Cam 2, Dist: 77m | Alert: True
# ✅ Saved: Cam 8, Dist: 213m | Alert: True
# ✅ Saved: Cam 1, Dist: 400m | Alert: True
# ✅ Saved: Cam 9, Dist: 95m | Alert: True
# ✅ Saved: Cam 7, Dist: 212m | Alert: True
# ✅ Saved: Cam 4, Dist: 340m | Alert: True
# ✅ Saved: Cam 5, Dist: 101m | Alert: True
# ✅ Saved: Cam 4, Dist: 307m | Alert: True
# ✅ Saved: Cam 2, Dist: 86m | Alert: True
# ✅ Saved: Cam 2, Dist: 242m | Alert: True
# ✅ Saved: Cam 10, Dist: 156m | Alert: True
# ✅ Saved: Cam 3, Dist: 242m | Alert: True
# ✅ Saved: Cam 8, Dist: 125m | Alert: True
# ✅ Saved: Cam 7, Dist: 335m | Alert: True
# ✅ Saved: Cam 9, Dist: 152m | Alert: True
# ✅ Saved: Cam 10, Dist: 140m | Alert: True
# ✅ Saved: Cam 7, Dist: 180m | Alert: True
# ✅ Saved: Cam 3, Dist: 185m | Alert: True
# ✅ Saved: Cam 3, Dist: 211m | Alert: True
# ✅ Saved: Cam 3, Dist: 259m | Alert: True
# ✅ Saved: Cam 3, Dist: 274m | Alert: True
# ✅ Saved: Cam 2, Dist: 229m | Alert: True
# ✅ Saved: Cam 6, Dist: 292m | Alert: True
# ✅ Saved: Cam 6, Dist: 251m | Alert: True
# ✅ Saved: Cam 9, Dist: 177m | Alert: True
# ✅ Saved: Cam 5, Dist: 194m | Alert: True
# ✅ Saved: Cam 6, Dist: 176m | Alert: True
# ✅ Saved: Cam 2, Dist: 145m | Alert: True
# ✅ Saved: Cam 5, Dist: 120m | Alert: True
# ✅ Saved: Cam 4, Dist: 316m | Alert: True
# ✅ Saved: Cam 7, Dist: 372m | Alert: True
# ✅ Saved: Cam 8, Dist: 121m | Alert: True
# ✅ Saved: Cam 6, Dist: 290m | Alert: True
# ✅ Saved: Cam 4, Dist: 407m | Alert: True
# ✅ Saved: Cam 9, Dist: 172m | Alert: True
# ✅ Saved: Cam 9, Dist: 148m | Alert: True
# ✅ Saved: Cam 1, Dist: 353m | Alert: True
# ✅ Saved: Cam 5, Dist: 133m | Alert: True
# ✅ Saved: Cam 3, Dist: 243m | Alert: True
# ✅ Saved: Cam 3, Dist: 138m | Alert: True
# ✅ Saved: Cam 3, Dist: 190m | Alert: True
# ✅ Saved: Cam 10, Dist: 80m | Alert: True
# ✅ Saved: Cam 4, Dist: 250m | Alert: True
# ✅ Saved: Cam 9, Dist: 165m | Alert: True
# ✅ Saved: Cam 10, Dist: 215m | Alert: True
# ✅ Saved: Cam 2, Dist: 179m | Alert: True
# ✅ Saved: Cam 10, Dist: 145m | Alert: True
# ✅ Saved: Cam 3, Dist: 166m | Alert: True
# ✅ Saved: Cam 5, Dist: 198m | Alert: True
# ✅ Saved: Cam 7, Dist: 322m | Alert: True
# ✅ Saved: Cam 3, Dist: 292m | Alert: True
# ✅ Saved: Cam 7, Dist: 317m | Alert: True
# ✅ Saved: Cam 7, Dist: 333m | Alert: True
# ✅ Saved: Cam 10, Dist: 62m | Alert: True
# ✅ Saved: Cam 5, Dist: 88m | Alert: True
# ✅ Saved: Cam 6, Dist: 152m | Alert: True
# ✅ Saved: Cam 4, Dist: 442m | Alert: True
# ✅ Saved: Cam 8, Dist: 181m | Alert: True
# ✅ Saved: Cam 7, Dist: 244m | Alert: True
# ✅ Saved: Cam 2, Dist: 112m | Alert: True
# ✅ Saved: Cam 9, Dist: 152m | Alert: True
# ✅ Saved: Cam 6, Dist: 154m | Alert: True
# ✅ Saved: Cam 2, Dist: 95m | Alert: True
# ✅ Saved: Cam 3, Dist: 214m | Alert: True
# ✅ Saved: Cam 7, Dist: 330m | Alert: True
# ✅ Saved: Cam 2, Dist: 72m | Alert: True
# ✅ Saved: Cam 10, Dist: 151m | Alert: True
# ✅ Saved: Cam 10, Dist: 15m | Alert: True
# ✅ Saved: Cam 5, Dist: 250m | Alert: True
# ✅ Saved: Cam 6, Dist: 121m | Alert: True
# ✅ Saved: Cam 5, Dist: 147m | Alert: True
# ✅ Saved: Cam 5, Dist: 176m | Alert: True
# ✅ Saved: Cam 5, Dist: 108m | Alert: True
# ✅ Saved: Cam 5, Dist: 106m | Alert: True
# ✅ Saved: Cam 10, Dist: 177m | Alert: True
# ✅ Saved: Cam 1, Dist: 376m | Alert: True
# ✅ Saved: Cam 4, Dist: 302m | Alert: True
# ✅ Saved: Cam 4, Dist: 274m | Alert: True
# ✅ Saved: Cam 2, Dist: 240m | Alert: True
# ✅ Saved: Cam 5, Dist: 8m | Alert: True
# ✅ Saved: Cam 6, Dist: 113m | Alert: True
# ✅ Saved: Cam 1, Dist: 253m | Alert: True
# ✅ Saved: Cam 7, Dist: 272m | Alert: True
# ✅ Saved: Cam 1, Dist: 345m | Alert: True
# ✅ Saved: Cam 5, Dist: 195m | Alert: True
# ✅ Saved: Cam 3, Dist: 286m | Alert: True
# ✅ Saved: Cam 10, Dist: 46m | Alert: True
# ✅ Saved: Cam 8, Dist: 196m | Alert: True
# ✅ Saved: Cam 2, Dist: 265m | Alert: True
# ✅ Saved: Cam 8, Dist: 234m | Alert: True
# ✅ Saved: Cam 10, Dist: 208m | Alert: True
# ✅ Saved: Cam 5, Dist: 218m | Alert: True
# ✅ Saved: Cam 8, Dist: 130m | Alert: True
# ✅ Saved: Cam 9, Dist: 212m | Alert: True
# ✅ Saved: Cam 7, Dist: 338m | Alert: True
# ✅ Saved: Cam 5, Dist: 134m | Alert: True
# ✅ Saved: Cam 6, Dist: 151m | Alert: True
# ✅ Saved: Cam 9, Dist: 141m | Alert: True
# ✅ Saved: Cam 2, Dist: 129m | Alert: True
# ✅ Saved: Cam 7, Dist: 160m | Alert: True
# ✅ Saved: Cam 8, Dist: 183m | Alert: True
# ✅ Saved: Cam 3, Dist: 202m | Alert: True
# ✅ Saved: Cam 7, Dist: 278m | Alert: True
# ✅ Saved: Cam 3, Dist: 270m | Alert: True
# ✅ Saved: Cam 8, Dist: 214m | Alert: True
# ✅ Saved: Cam 8, Dist: 186m | Alert: True
# ✅ Saved: Cam 1, Dist: 307m | Alert: True
# ✅ Saved: Cam 9, Dist: 230m | Alert: True
# ✅ Saved: Cam 3, Dist: 267m | Alert: True
# ✅ Saved: Cam 4, Dist: 343m | Alert: True
# ✅ Saved: Cam 9, Dist: 113m | Alert: True
# ✅ Saved: Cam 1, Dist: 409m | Alert: True
# ✅ Saved: Cam 3, Dist: 121m | Alert: True
# ✅ Saved: Cam 9, Dist: 132m | Alert: True
# ✅ Saved: Cam 10, Dist: 134m | Alert: True
# ✅ Saved: Cam 7, Dist: 325m | Alert: True
# ✅ Saved: Cam 8, Dist: 184m | Alert: True
# ✅ Saved: Cam 6, Dist: 106m | Alert: True
# ✅ Saved: Cam 9, Dist: 119m | Alert: True
# ✅ Saved: Cam 3, Dist: 318m | Alert: True
# ✅ Saved: Cam 9, Dist: 113m | Alert: True
# ✅ Saved: Cam 4, Dist: 353m | Alert: True
# ✅ Saved: Cam 3, Dist: 151m | Alert: True
# ✅ Saved: Cam 5, Dist: 210m | Alert: True
# ✅ Saved: Cam 5, Dist: 204m | Alert: True
# ✅ Saved: Cam 4, Dist: 412m | Alert: True
# ✅ Saved: Cam 6, Dist: 210m | Alert: True
# ✅ Saved: Cam 4, Dist: 220m | Alert: True
# ✅ Saved: Cam 8, Dist: 232m | Alert: True
# ✅ Saved: Cam 9, Dist: 41m | Alert: True
# ✅ Saved: Cam 9, Dist: 57m | Alert: True
# ✅ Saved: Cam 5, Dist: 140m | Alert: True
# ✅ Saved: Cam 8, Dist: 272m | Alert: True
# ✅ Saved: Cam 4, Dist: 382m | Alert: True
# ✅ Saved: Cam 4, Dist: 319m | Alert: True
# ✅ Saved: Cam 9, Dist: 129m | Alert: True
# ✅ Saved: Cam 3, Dist: 260m | Alert: True
# ✅ Saved: Cam 1, Dist: 235m | Alert: True
# ✅ Saved: Cam 7, Dist: 298m | Alert: True
# ✅ Saved: Cam 5, Dist: 75m | Alert: True
# ✅ Saved: Cam 3, Dist: 172m | Alert: True
# ✅ Saved: Cam 10, Dist: 147m | Alert: True
# ✅ Saved: Cam 1, Dist: 377m | Alert: True
# ✅ Saved: Cam 2, Dist: 159m | Alert: True
# ✅ Saved: Cam 9, Dist: 55m | Alert: True
# ✅ Saved: Cam 2, Dist: 109m | Alert: True
# ✅ Saved: Cam 10, Dist: 62m | Alert: True
# ✅ Saved: Cam 3, Dist: 172m | Alert: True
# ✅ Saved: Cam 2, Dist: 124m | Alert: True
# ✅ Saved: Cam 7, Dist: 157m | Alert: True
# ✅ Saved: Cam 5, Dist: 152m | Alert: True
# ✅ Saved: Cam 8, Dist: 271m | Alert: True
# ✅ Saved: Cam 8, Dist: 288m | Alert: True
# ✅ Saved: Cam 9, Dist: 147m | Alert: True
# ✅ Saved: Cam 1, Dist: 375m | Alert: True
# ✅ Saved: Cam 7, Dist: 283m | Alert: True
# ✅ Saved: Cam 10, Dist: 172m | Alert: True
# ✅ Saved: Cam 1, Dist: 361m | Alert: True
# ✅ Saved: Cam 6, Dist: 73m | Alert: True
# ✅ Saved: Cam 5, Dist: 135m | Alert: True
# ✅ Saved: Cam 9, Dist: 89m | Alert: True
# ✅ Saved: Cam 10, Dist: 112m | Alert: True
# ✅ Saved: Cam 6, Dist: 104m | Alert: True
# ✅ Saved: Cam 10, Dist: 240m | Alert: True
# ✅ Saved: Cam 6, Dist: 296m | Alert: True
# ✅ Saved: Cam 8, Dist: 186m | Alert: True
# ✅ Saved: Cam 4, Dist: 320m | Alert: True
# ✅ Saved: Cam 1, Dist: 405m | Alert: True
# ✅ Saved: Cam 1, Dist: 362m | Alert: True
# ✅ Saved: Cam 10, Dist: 162m | Alert: True
# ✅ Saved: Cam 7, Dist: 226m | Alert: True
# ✅ Saved: Cam 4, Dist: 252m | Alert: True
# ✅ Saved: Cam 5, Dist: 90m | Alert: True
# ✅ Saved: Cam 2, Dist: 143m | Alert: True
# ✅ Saved: Cam 6, Dist: 155m | Alert: True
# ✅ Saved: Cam 2, Dist: 209m | Alert: True
# ✅ Saved: Cam 9, Dist: 195m | Alert: True
# ✅ Saved: Cam 4, Dist: 378m | Alert: True
# ✅ Saved: Cam 7, Dist: 136m | Alert: True
# ✅ Saved: Cam 10, Dist: 138m | Alert: True
# ✅ Saved: Cam 3, Dist: 144m | Alert: True
# ✅ Saved: Cam 6, Dist: 143m | Alert: True
# ✅ Saved: Cam 8, Dist: 157m | Alert: True
# ✅ Saved: Cam 7, Dist: 345m | Alert: True
# ✅ Saved: Cam 4, Dist: 327m | Alert: True
# ✅ Saved: Cam 2, Dist: 198m | Alert: True
# ✅ Saved: Cam 2, Dist: 167m | Alert: True
# ✅ Saved: Cam 5, Dist: 74m | Alert: True
# ✅ Saved: Cam 8, Dist: 280m | Alert: True
# ✅ Saved: Cam 10, Dist: 140m | Alert: True
# ✅ Saved: Cam 10, Dist: 126m | Alert: True
# ✅ Saved: Cam 9, Dist: 31m | Alert: True
# ✅ Saved: Cam 9, Dist: 172m | Alert: True
# ✅ Saved: Cam 3, Dist: 297m | Alert: True
# 🔁 Processed 500 messages, exiting.
